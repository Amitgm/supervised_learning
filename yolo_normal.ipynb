# %% [markdown]
# <a href="https://colab.research.google.com/github/Amitgm/supervised_learning/blob/master/yolo_normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SUBSCRIBE to the [channel](https://www.youtube.com/user/19daredevill?sub_confirmation=1) to learn cool things**

# %% [markdown]
# **Step 1 : Clone yolov5 repository**

# %%
# !git clone https://github.com/ultralytics/yolov5.git # cloning the repository
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13003, done.
# remote: Total 13003 (delta 0), reused 0 (delta 0), pack-reused 13003
# Receiving objects: 100% (13003/13003), 11.86 MiB | 29.19 MiB/s, done.
# Resolving deltas: 100% (9037/9037), done.

# %% [markdown]
# **Step 2: Change Directory to yolov5**

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %% [markdown]
# **Step 3: Install Dependencies**

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 29.6 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 44.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |█████████████▎                  | 311.6 MB 1.5 MB/s eta 0:04:50ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/urllib3/response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/cachecontrol/filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "/usr/lib/python3.7/http/client.py", line 465, in read
#     n = self.readinto(b)
# ...

# %% [markdown]
# **Step 4: Run Object Detection on Images. Provide image path. Upload image in the inference/images/ folder**

# %%
# !python detect.py --source ./data/images/desk.jpg --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=./data/images/desk.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-161-ge54e758 torch 1.11.0+cu102 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 126MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Traceback (most recent call last):
#   File "detect.py", line 252, in <module>
#     main(opt)
#   File "detect.py", line 247, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 103, in run
# ...

# %%
# !python yolov5/detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source '/content/rgb/'

# %% [markdown]
# **Step 5: Display image in colab**

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("runs/detect/exp6/desk.jpg")
#image= cv2.imread("data/images/people.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))

# %% [markdown]
# **Object Detection on Videos. Create a folder under inference/ called "videos", under which you can upload the video file and then provide the file path below**

# %%
# !python detect.py --source inference/videos/running.mp4 --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='inference/videos/running.mp4', update=False, view_img=False, weights=['yolov5s.pt'])
# Using CPU
#
# Fusing layers... Model Summary: 140 layers, 7.45958e+06 parameters, 7.45958e+06 gradients
# video 1/1 (1/469) /content/yolov5/inference/videos/running.mp4: 384x640 1 persons, Done. (0.412s)
# video 1/1 (2/469) /content/yolov5/inference/videos/running.mp4: 384x640 1 persons, Done. (0.329s)
# video 1/1 (3/469) /content/yolov5/inference/videos/running.mp4: 384x640 1 persons, Done. (0.290s)
# video 1/1 (4/469) /content/yolov5/inference/videos/running.mp4: 384x640 2 persons, Done. (0.297s)
# video 1/1 (5/469) /content/yolov5/inference/videos/running.mp4: 384x640 2 persons, Done. (0.285s)
# video 1/1 (6/469) /content/yolov5/inference/videos/running.mp4: 384x640 2 persons, Done. (0.282s)
# ...
